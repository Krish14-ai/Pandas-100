# %% [markdown]
# # 100 Pandas Exercises
#
# A graded set of practice problems for building Pandas fluency.

# %% [markdown]
# This notebook contains **100 Pandas practice exercises**, ordered roughly from easy to hard and marked with a difficulty rating:
#
# - ★☆☆ = easy
# - ★★☆ = medium
# - ★★★ = hard
#
# Each question has an empty code cell below it for you to write your solution. **No answers are provided** — look things up in the [Pandas documentation](https://pandas.pydata.org/docs/) when you get stuck, that's part of the practice. Some exercises assume you have a sample DataFrame loaded or that you create your own small sample data — feel free to invent realistic sample data where none is given.

# %% [markdown]
# Run the setup cell below once before starting.

# %%
import pandas as pd
import numpy as np
np.random.seed(42)  # for reproducibility where randomness is used

# %% [markdown]
# #### 1. Import pandas under the alias `pd` and print its version. (★☆☆)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.1

# %% [markdown]
# #### 2. Create a pandas Series from the list [10, 20, 30, 40, 50]. (★☆☆)

# %%
df = pd.Series([1,2,3,4])
print(df)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# #### 3. Create a Series with a custom index made of the letters a, b, c, d, e. (★☆☆)

# %%
df = pd.Series(data = [1,2,3,4],index = ['a','b','c','d'])
print(df)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# #### 4. Create a DataFrame from a dictionary of three columns: name, age, and city (5 rows). (★☆☆)

# %%
dict = {
    'Name' : ['Krish','Karan','Priyanka','Pallavi','Aaru'],
    'Age' : [20,18,43,18,2],
    'city': ['Bareilly','Bareilly','Bareilly','Bareilly','Bareilly']
}
df = pd.DataFrame(dict)
print(df)
# Out:
#        Name  Age      city
# 0     Krish   20  Bareilly
# 1     Karan   18  Bareilly
# 2  Priyanka   43  Bareilly
# 3   Pallavi   18  Bareilly
# 4      Aaru    2  Bareilly

# %% [markdown]
# #### 5. Read a CSV file into a DataFrame and display the first 5 rows. (★☆☆)

# %%
df = pd.read_csv(r'train.csv')
df.head(5)
# Out:
#    id health_condition  sleep_duration  heart_rate    bmi  \
# 0   0        unhealthy            5.22        70.6  25.66
# 1   1          at-risk            5.53        71.3  25.84
# 2   2        unhealthy            5.29        75.4  24.54
# 3   3        unhealthy            4.70        77.2  23.13
# 4   4          at-risk            7.23        73.4  28.44
#
#    calorie_expenditure  step_count  exercise_duration  water_intake diet_type  \
# 0               2174.0      1326.0               19.8          1.86       veg
# 1               1966.0      9891.0               49.9          1.26   non-veg
# 2               2688.0     14216.0               38.1          1.60       veg
# 3               2630.0      7174.0               59.9          2.02       veg
# 4               2560.0      6584.0               46.0          2.25       veg
#
#   stress_level sleep_quality physical_activity_level smoking_alcohol  gender
# ...

# %% [markdown]
# #### 6. Display the shape, column names, and data types of a DataFrame. (★☆☆)

# %%
shape = df.shape
columns = df.columns.tolist()
dtypes = df.dtypes
print("Shape : ", shape,'\n')
print("columns : ",columns,'\n')
print('dtypes :',dtypes)
# Out:
# Shape :  (690088, 15)
#
# columns :  ['id', 'health_condition', 'sleep_duration', 'heart_rate', 'bmi', 'calorie_expenditure', 'step_count', 'exercise_duration', 'water_intake', 'diet_type', 'stress_level', 'sleep_quality', 'physical_activity_level', 'smoking_alcohol', 'gender']
#
# dtypes : id                           int64
# health_condition               str
# sleep_duration             float64
# heart_rate                 float64
# bmi                        float64
# calorie_expenditure        float64
# step_count                 float64
# exercise_duration          float64
# water_intake               float64
# diet_type                      str
# stress_level                   str
# sleep_quality                  str
# physical_activity_level        str
# smoking_alcohol                str
# gender                         str
# dtype: object

# %% [markdown]
# #### 7. Select a single column from a DataFrame and confirm it returns a Series. (★☆☆)

# %%
first_col = df.iloc[:,0]
print(type(first_col))
print(first_col)
# Out:
# <class 'pandas.Series'>
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 690083    690083
# 690084    690084
# 690085    690085
# 690086    690086
# 690087    690087
# Name: id, Length: 690088, dtype: int64

# %% [markdown]
# #### 8. Select multiple columns from a DataFrame at once. (★☆☆)

# %%
cols = df.iloc[1:,0:4]
print(cols)
# Out:
#             id health_condition  sleep_duration  heart_rate
# 1            1          at-risk            5.53        71.3
# 2            2        unhealthy            5.29        75.4
# 3            3        unhealthy            4.70        77.2
# 4            4          at-risk            7.23        73.4
# 5            5          at-risk            5.11        82.8
# ...        ...              ...             ...         ...
# 690083  690083          at-risk            6.31        69.7
# 690084  690084          at-risk            5.78        54.0
# 690085  690085              fit            7.64        85.7
# 690086  690086          at-risk            6.74        73.0
# 690087  690087          at-risk            5.55        69.3
#
# [690087 rows x 4 columns]

# %% [markdown]
# #### 9. Select rows of a DataFrame by position using `.iloc`. (★☆☆)

# %%
rows = df.iloc[0:3]
print(rows)
# Out:
#    id health_condition  sleep_duration  heart_rate    bmi  \
# 0   0        unhealthy            5.22        70.6  25.66
# 1   1          at-risk            5.53        71.3  25.84
# 2   2        unhealthy            5.29        75.4  24.54
#
#    calorie_expenditure  step_count  exercise_duration  water_intake diet_type  \
# 0               2174.0      1326.0               19.8          1.86       veg
# 1               1966.0      9891.0               49.9          1.26   non-veg
# 2               2688.0     14216.0               38.1          1.60       veg
#
#   stress_level sleep_quality physical_activity_level smoking_alcohol  gender
# 0         high       average               sedentary             yes  female
# 1          low       average                moderate             yes   other
# 2         high          poor                  active             yes    male

# %% [markdown]
# #### 10. Select rows of a DataFrame by label using `.loc`. (★☆☆)

# %%
rows = df['id'].iloc[1:4]
print(rows)
# Out:
# 1    1
# 2    2
# 3    3
# Name: id, dtype: int64

# %% [markdown]
# #### 11. Filter rows of a DataFrame where a numeric column exceeds a given threshold. (★☆☆)

# %%
rows = [df['calorie_expenditure'] > 3000]
print(rows)
# Out:
# [0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 690083    False
# 690084    False
# 690085    False
# 690086    False
# 690087    False
# Name: calorie_expenditure, Length: 690088, dtype: bool]

# %% [markdown]
# #### 12. Filter rows using multiple conditions combined with `&` and `|`. (★★☆)

# %% [markdown]
# #### 13. Sort a DataFrame by one column in descending order. (★☆☆)

# %% [markdown]
# #### 14. Sort a DataFrame by two columns, ascending on one and descending on another. (★★☆)

# %% [markdown]
# #### 15. Rename one or more columns of a DataFrame. (★☆☆)

# %% [markdown]
# #### 16. Add a new column to a DataFrame computed from two existing columns. (★☆☆)

# %% [markdown]
# #### 17. Drop a column from a DataFrame. (★☆☆)

# %% [markdown]
# #### 18. Drop rows containing any missing values. (★☆☆)

# %% [markdown]
# #### 19. Count the number of missing values in each column of a DataFrame. (★☆☆)

# %% [markdown]
# #### 20. Fill missing values in a column with the column's mean. (★☆☆)

# %% [markdown]
# #### 21. Fill missing values differently per column using a dictionary passed to `fillna`. (★★☆)

# %% [markdown]
# #### 22. Replace all missing values in a DataFrame with a placeholder string 'unknown'. (★☆☆)

# %% [markdown]
# #### 23. Detect and remove duplicate rows from a DataFrame. (★☆☆)

# %% [markdown]
# #### 24. Detect duplicate rows based on a subset of columns only. (★★☆)

# %% [markdown]
# #### 25. Compute basic summary statistics (mean, std, min, max) for all numeric columns using `.describe()`. (★☆☆)

# %% [markdown]
# #### 26. Compute the correlation matrix between numeric columns of a DataFrame. (★★☆)

# %% [markdown]
# #### 27. Group a DataFrame by a categorical column and compute the mean of another column per group. (★☆☆)

# %% [markdown]
# #### 28. Group by two columns simultaneously and compute the sum of a numeric column. (★★☆)

# %% [markdown]
# #### 29. Use `.agg()` to compute multiple aggregate statistics (mean, min, max) per group at once. (★★☆)

# %% [markdown]
# #### 30. Use `.transform()` to add a column containing each group's mean alongside the original rows. (★★☆)

# %% [markdown]
# #### 31. Find the group in a groupby object with the highest total sum for a given column. (★★☆)

# %% [markdown]
# #### 32. Reset the index of a DataFrame after a groupby operation. (★☆☆)

# %% [markdown]
# #### 33. Set a column of a DataFrame as its index. (★☆☆)

# %% [markdown]
# #### 34. Reset a DataFrame's index back to the default integer index. (★☆☆)

# %% [markdown]
# #### 35. Create a MultiIndex DataFrame from two categorical columns. (★★☆)

# %% [markdown]
# #### 36. Select data from a MultiIndex DataFrame using `.xs()`. (★★★)

# %% [markdown]
# #### 37. Pivot a long-format DataFrame into a wide format using `.pivot()`. (★★☆)

# %% [markdown]
# #### 38. Create a pivot table that computes the mean of a value column, grouped by two other columns. (★★☆)

# %% [markdown]
# #### 39. Melt a wide-format DataFrame back into long format using `.melt()`. (★★☆)

# %% [markdown]
# #### 40. Concatenate two DataFrames vertically (stack rows). (★☆☆)

# %% [markdown]
# #### 41. Concatenate two DataFrames horizontally (align on index). (★☆☆)

# %% [markdown]
# #### 42. Merge two DataFrames on a common key column using an inner join. (★☆☆)

# %% [markdown]
# #### 43. Merge two DataFrames using a left join and identify rows with no match. (★★☆)

# %% [markdown]
# #### 44. Merge two DataFrames on multiple key columns. (★★☆)

# %% [markdown]
# #### 45. Join two DataFrames using their indexes with `.join()`. (★★☆)

# %% [markdown]
# #### 46. Perform a full outer join between two DataFrames and count unmatched rows on each side. (★★☆)

# %% [markdown]
# #### 47. Apply a custom function to every element of a column using `.apply()`. (★☆☆)

# %% [markdown]
# #### 48. Apply a function row-wise across a DataFrame using `axis=1`. (★★☆)

# %% [markdown]
# #### 49. Use `.map()` to replace category codes in a column with their meaning using a dictionary. (★☆☆)

# %% [markdown]
# #### 50. Bin a continuous numeric column into categorical ranges using `pd.cut()`. (★★☆)

# %% [markdown]
# #### 51. Bin a numeric column into equal-sized quantile groups using `pd.qcut()`. (★★☆)

# %% [markdown]
# #### 52. Convert a column of strings to a `category` dtype and inspect the memory savings. (★★☆)

# %% [markdown]
# #### 53. Extract the value counts (frequency) of each category in a column. (★☆☆)

# %% [markdown]
# #### 54. Compute the proportion (relative frequency) of each category in a column. (★☆☆)

# %% [markdown]
# #### 55. Convert a column of date strings into a proper `datetime64` dtype. (★☆☆)

# %% [markdown]
# #### 56. Extract the year, month, and day from a datetime column into separate columns. (★☆☆)

# %% [markdown]
# #### 57. Filter a DataFrame to only rows within a specific date range. (★★☆)

# %% [markdown]
# #### 58. Set a datetime column as the index and resample it to compute monthly averages. (★★☆)

# %% [markdown]
# #### 59. Compute a 7-day rolling mean of a time series column. (★★☆)

# %% [markdown]
# #### 60. Compute the difference between consecutive rows of a time series using `.diff()`. (★☆☆)

# %% [markdown]
# #### 61. Compute percentage change between consecutive rows using `.pct_change()`. (★☆☆)

# %% [markdown]
# #### 62. Shift a time series column forward by one period using `.shift()`. (★☆☆)

# %% [markdown]
# #### 63. Reindex a time series DataFrame to fill in missing dates, forward-filling values. (★★☆)

# %% [markdown]
# #### 64. Use `.str.contains()` to filter rows where a text column contains a given substring. (★☆☆)

# %% [markdown]
# #### 65. Use `.str.split()` to split a full-name column into first name and last name columns. (★★☆)

# %% [markdown]
# #### 66. Strip whitespace and convert a text column to lowercase using string accessor methods. (★☆☆)

# %% [markdown]
# #### 67. Extract a substring from a text column using a regular expression with `.str.extract()`. (★★☆)

# %% [markdown]
# #### 68. Replace substrings in a text column using `.str.replace()` with a regular expression. (★★☆)

# %% [markdown]
# #### 69. Compute the length of each string in a text column. (★☆☆)

# %% [markdown]
# #### 70. Create a DataFrame with a column of comma-separated values and explode it into multiple rows. (★★☆)

# %% [markdown]
# #### 71. Select every other row of a DataFrame using slicing. (★☆☆)

# %% [markdown]
# #### 72. Use `.query()` to filter a DataFrame with a string expression instead of boolean indexing. (★★☆)

# %% [markdown]
# #### 73. Use `np.where` (or `.loc`) to create a new column with conditional values based on another column. (★★☆)

# %% [markdown]
# #### 74. Use `pd.cut` combined with `.value_counts()` to build a histogram-like frequency table. (★★☆)

# %% [markdown]
# #### 75. Compute the cumulative sum and cumulative maximum of a numeric column. (★☆☆)

# %% [markdown]
# #### 76. Find the index of the row with the maximum value in a column using `.idxmax()`. (★☆☆)

# %% [markdown]
# #### 77. Select the top 3 rows per group after grouping by a categorical column. (★★☆)

# %% [markdown]
# #### 78. Compute a weighted average of one column using weights from another column. (★★☆)

# %% [markdown]
# #### 79. Normalize a numeric column to have zero mean and unit variance (z-score). (★★☆)

# %% [markdown]
# #### 80. Min-max scale a numeric column to the range [0, 1]. (★★☆)

# %% [markdown]
# #### 81. Create a random DataFrame and randomly sample 20% of its rows without replacement. (★☆☆)

# %% [markdown]
# #### 82. Split a DataFrame into training and test sets by randomly sampling row indices. (★★☆)

# %% [markdown]
# #### 83. Chain multiple operations (filter, groupby, sort) together using method chaining. (★★☆)

# %% [markdown]
# #### 84. Use `.pipe()` to apply a custom transformation function as part of a method chain. (★★☆)

# %% [markdown]
# #### 85. Detect outliers in a numeric column using the interquartile range (IQR) method. (★★☆)

# %% [markdown]
# #### 86. Cap (winsorize) outlier values in a numeric column at the 1st and 99th percentiles. (★★★)

# %% [markdown]
# #### 87. Compute a rolling z-score of a time series to flag anomalies. (★★★)

# %% [markdown]
# #### 88. Create a crosstab (contingency table) between two categorical columns. (★★☆)

# %% [markdown]
# #### 89. Normalize a crosstab so that each row sums to 1 (row-wise proportions). (★★☆)

# %% [markdown]
# #### 90. Write a DataFrame to a CSV file without the index column. (★☆☆)

# %% [markdown]
# #### 91. Write a DataFrame to an Excel file with a named sheet. (★☆☆)

# %% [markdown]
# #### 92. Read a JSON string or file into a DataFrame with `pd.read_json()`. (★☆☆)

# %% [markdown]
# #### 93. Convert a DataFrame to a list of dictionaries using `.to_dict(orient='records')`. (★☆☆)

# %% [markdown]
# #### 94. Use `.eval()` to compute a new column from an arithmetic expression on existing columns. (★★☆)

# %% [markdown]
# #### 95. Optimize the memory usage of a DataFrame by downcasting numeric dtypes. (★★★)

# %% [markdown]
# #### 96. Merge two DataFrames with overlapping column names, using suffixes to disambiguate them. (★★☆)

# %% [markdown]
# #### 97. Compute a rolling correlation between two numeric columns over a moving window. (★★★)

# %% [markdown]
# #### 98. Given a DataFrame with a MultiIndex on columns, select a specific sub-column group. (★★★)

# %% [markdown]
# #### 99. Use `groupby().apply()` with a custom function that returns a DataFrame, then combine results. (★★★)

# %% [markdown]
# #### 100. Use `pd.merge_asof()` to join two time-ordered DataFrames on the nearest timestamp. (★★★)
